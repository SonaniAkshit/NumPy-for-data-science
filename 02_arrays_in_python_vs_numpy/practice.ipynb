# %% [markdown]
# ## *2.1 Arrays in Python vs NumPy*
#
# ### Simple Practice
# *1. Create a Python list and a NumPy array with same values and compare their types.*

# %%
import numpy as np
import array

# %%
# list 
l1 = [1,6,8,3,4]
